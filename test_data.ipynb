# %%
import numpy as np
import cv2 as cv
import sys
import os
import glob


TRAINING_FILE_NAME            = "haarcascade_frontalface_alt.xml"

def showHelp():
    print("Author: hoaint.13")
    #print("--help/-h\tShow usage help")
    print("usage: face_detector_hoai <image file name>")
    print("Ex: face_detector_hoai demo.jpg") 



if __name__ == '__main__':
    if len(sys.argv) != 2:
        showHelp()
        exit(1)

    imageFileName = sys.argv[1]
    face_cascade = cv.CascadeClassifier(TRAINING_FILE_NAME)
           
    path = glob.glob("FC/*.png")    
    for ipath in path:
        img = cv.imread(ipath)
        print(ipath)
        TenAnh = ipath.split("\\")[-1]
        print('ten anh' + TenAnh)
        Ten = TenAnh.split(".")[0]
        print('ten' + Ten)
   
        gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
        face_crop = []
        for (x,y,w,h) in faces:
            cv.rectangle(img,(x,y),(x+w,y+h),(0, 0, 255),2)
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = img[y:y+h, x:x+w]
            face_crop.append(img[y:y+h, x:x+w])


        faceFileName = "faces_" + imageFileName
    

        print ("Successfully saved the results to %s" %(Ten))

        for i in range(0,len(face_crop)):
            face_crop_name = 'Result/' + Ten + "_face_" +str(i) + ".jpg"
            print(face_crop_name)
            cv.imwrite(face_crop_name, face_crop[i])
# Out:
# Author: hoaint.13
# usage: face_detector_hoai <image file name>
# Ex: face_detector_hoai demo.jpg
# FC\Feb 26- 2019 at 5-08 PM.png
# ten anhFeb 26- 2019 at 5-08 PM.png
# tenFeb 26- 2019 at 5-08 PM
# Successfully saved the results to Feb 26- 2019 at 5-08 PM
# Result/Feb 26- 2019 at 5-08 PM_face_0.jpg
# Result/Feb 26- 2019 at 5-08 PM_face_1.jpg
# Result/Feb 26- 2019 at 5-08 PM_face_2.jpg
# Result/Feb 26- 2019 at 5-08 PM_face_3.jpg
# Result/Feb 26- 2019 at 5-08 PM_face_4.jpg
# FC\Feb 26- 2019 at 5-09 PM.png
# ten anhFeb 26- 2019 at 5-09 PM.png
# tenFeb 26- 2019 at 5-09 PM
# Successfully saved the results to Feb 26- 2019 at 5-09 PM
# Result/Feb 26- 2019 at 5-09 PM_face_0.jpg
# FC\Feb 26- 2019 at 5-10 PM.png
# ten anhFeb 26- 2019 at 5-10 PM.png
# tenFeb 26- 2019 at 5-10 PM
# Successfully saved the results to Feb 26- 2019 at 5-10 PM
# Result/Feb 26- 2019 at 5-10 PM_face_0.jpg
# Result/Feb 26- 2019 at 5-10 PM_face_1.jpg
# FC\Feb 26- 2019 at 6-09 PM.png
# ten anhFeb 26- 2019 at 6-09 PM.png
# tenFeb 26- 2019 at 6-09 PM
# Successfully saved the results to Feb 26- 2019 at 6-09 PM
# Result/Feb 26- 2019 at 6-09 PM_face_0.jpg
# Result/Feb 26- 2019 at 6-09 PM_face_1.jpg
# Result/Feb 26- 2019 at 6-09 PM_face_2.jpg
# Result/Feb 26- 2019 at 6-09 PM_face_3.jpg
# Result/Feb 26- 2019 at 6-09 PM_face_4.jpg
# Result/Feb 26- 2019 at 6-09 PM_face_5.jpg
